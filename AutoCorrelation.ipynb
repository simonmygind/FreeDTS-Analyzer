# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from scipy.stats import norm
import os
from scipy.optimize import curve_fit

from brokenaxes import brokenaxes

import scienceplots
plt.style.use(['science', 'ieee'])
plt.rcParams['figure.dpi'] = 300
from PythonAnalysis import *

# %%
FTMethod = "DFT"
kappa = 20
FrameTension="IsotropicFrameTension"
InitialConfiguration = "FromFlat"
N_k = 5
VFF="no"
i1 = 0; i2 = 10

# %%
spectra = [UndulationSpectrum(FrameTension,InitialConfiguration,"OnlyMembrane",FTMethod,kappa=20,N_k=N_k,EPS="no"),
            UndulationSpectrum(FrameTension,InitialConfiguration,"OnlyVectorField",FTMethod,kappa=20,N_k=N_k,EPS="1"),
            UndulationSpectrum(FrameTension,InitialConfiguration,"OnlyVectorField",FTMethod,kappa=20,N_k=N_k,EPS="2"),
            UndulationSpectrum(FrameTension,InitialConfiguration,"OnlyVectorField",FTMethod,kappa=20,N_k=N_k,EPS="5")
            ]
UndulationSpectrum.plot_autocorrelation(spectra, q_index=2, GroupBy=["EPS"],dt2=100)

# %%
FrameTension="IsotropicFrameTension"
InitialConfiguration = "FromFlat"
spectra = [UndulationSpectrum(FrameTension,InitialConfiguration,"OnlyMembrane",FTMethod,    kappa=10,N_k=N_k,EPS="no"),
            UndulationSpectrum(FrameTension,InitialConfiguration,"OnlyVectorField",FTMethod,kappa=10,N_k=N_k,EPS="1"),
            UndulationSpectrum(FrameTension,InitialConfiguration,"OnlyVectorField",FTMethod,kappa=10,N_k=N_k,EPS="2"),
            UndulationSpectrum(FrameTension,InitialConfiguration,"OnlyVectorField",FTMethod,kappa=10,N_k=N_k,EPS="5")
            ]
UndulationSpectrum.plot_autocorrelation(spectra, q_index=2, GroupBy=["EPS"],dt2=100)
