# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import os
from scipy.optimize import curve_fit

import scienceplots
plt.style.use(['science', 'ieee'])
plt.rcParams['figure.dpi'] = 300
from PythonAnalysis import *

# %%
FTMethod = "DFT"
kappa = 20
FrameTension="IsotropicFrameTension"
InitialConfiguration = "FromFlat"
Simulation="OnlyVectorField"
N_k = 10

# %%
spec = UndulationSpectrum(FrameTension, InitialConfiguration,
                            Simulation, FTMethod, N_k, EPS="1",VFF="1")
spec.plot("qxqy", i1=1, i2=8)

# %%
spec = UndulationSpectrum(FrameTension, InitialConfiguration,
                            Simulation, FTMethod, N_k, EPS="1",VFF="1")
spec.plot("qxqy", i1=1, i2=8, fit_func=True)

# %%
spec = UndulationSpectrum(FrameTension, InitialConfiguration,
                            Simulation, FTMethod, N_k, EPS="1",VFF="1")
spec.plot("qxqy", i1=0, i2=5, fit_func=True)
