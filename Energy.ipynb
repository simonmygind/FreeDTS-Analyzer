# %%
import numpy as np
import matplotlib.pyplot as plt
#/lustre/astro/semygind/Data/MembraneInclusion/KPKL/KP10KL5/dts-en.xvg

# %%
KPKL="NoVectorField"
values = np.genfromtxt(
    f"/lustre/astro/semygind/Data/MembraneInclusion/KPKL/{KPKL}/dts-en.xvg",
    skip_header=1,
    delimiter=" ",
)
# Out:
# /tmp/ipykernel_3115317/2381538889.py:2: UserWarning: genfromtxt: Empty input file: "/lustre/astro/semygind/Data/MembraneInclusion/KPKL/NoVectorField/dts-en.xvg"
#   values = np.genfromtxt(
