# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import os
from scipy.optimize import curve_fit

import scienceplots
plt.style.use(['science', 'ieee'])
plt.rcParams['figure.dpi'] = 300
from PythonAnalysis import *

# %%
FTMethod = "LSFT"
kappa = 20
FrameTension="AnisotropicFrameTension"
N_k = 10

# %%
#Simulation = "OnlyMembrane"
InitialConfiguration = "FromFlat"
Simulation = "OnlyVectorField"
UndulationSpectrum(VFF="1",InitialConfiguration=InitialConfiguration,plot_func="q",N_bootstrap=10000,i1=0,i2=5,
                   FrameTension=FrameTension,Simulation=Simulation,FTMethod=FTMethod,fit_func=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 4
#       2 InitialConfiguration = "FromFlat"
#       3 Simulation = "OnlyVectorField"
# ----> 4 UndulationSpectrum(InitialConfiguration=InitialConfiguration,plot_func="q",N_bootstrap=10000,i1=0,i2=5,
#       5                    FrameTension=FrameTension,Simulation=Simulation,FTMethod=FTMethod,fit_func=True)
#
# File /lustre/astro/semygind/Analyzer/version_1/PythonAnalysis.py:293, in UndulationSpectrum(InitialConfiguration, plot_func, i1, i2, FrameTension, Simulation, N_bootstrap, fit_func, N_r, FTMethod, N_k, VFF, EPS, KP, KL, XI, fig, ax, return_fig, ChainVars)
#     291 XI_str=f"XI{XI}/" if (XI != "no") else ""
#     292 AnalysisFile = f"{FrameTension}/{InitialConfiguration}/{Simulation}/VFF{VFF}/EPS{EPS}/{KPKL_str}{XI_str}StaticUndulationSpectrum/{FTMethod}{N_k}.txt"
# --> 293 data = load_boxsize_fourier_file(AnalysisFile)
#     294 N_r = data[('q', '<u u>')][i1:, 1:].shape[1]
#     298 ChainVars = ChainVars or []
#
# File /lustre/astro/semygind/Analyzer/version_1/PythonAnalysis.py:8, in load_boxsize_fourier_file(path)
#       7 def load_boxsize_fourier_file(path):
# ----> 8     with open(path, 'r') as f:
#       9         lines = f.readlines()
#      11     # --- parse metadata ---
#
# FileNotFoundError: [Errno 2] No such file or directory: 'AnisotropicFrameTension/FromFlat/OnlyVectorField/VFFno/EPSno/StaticUndulationSpectrum/LSFT10.txt'

# %%
Simulation = "OnlyVectorField"
UndulationSpectrum(EPS="1",InitialConfiguration=InitialConfiguration,plot_func="q",N_bootstrap=10000,i1=0,i2=5,
                   FrameTension=FrameTension,Simulation=Simulation,FTMethod=FTMethod,fit_func=True)

# %%
Simulation = "OnlyMembrane"
fig, ax = UndulationSpectrum(InitialConfiguration=InitialConfiguration,plot_func="q",N_bootstrap=10000,i1=0,i2=5,
                            FrameTension=FrameTension,Simulation=Simulation,FTMethod=FTMethod,
                            return_fig=True,GroupBy=["EPS"])

Simulation = "OnlyVectorField"
fig, ax = UndulationSpectrum(EPS="1",InitialConfiguration=InitialConfiguration,plot_func="q",N_bootstrap=10000,i1=0,i2=5,
                            FrameTension=FrameTension,Simulation=Simulation,FTMethod=FTMethod,
                            return_fig=True,fig=fig,ax=ax,GroupBy=["EPS"])
fig, ax = UndulationSpectrum(EPS="2",InitialConfiguration=InitialConfiguration,plot_func="q",N_bootstrap=10000,i1=0,i2=5,
                            FrameTension=FrameTension,Simulation=Simulation,FTMethod=FTMethod,
                            return_fig=True,fig=fig,ax=ax,GroupBy=["EPS"])
UndulationSpectrum(EPS="5",InitialConfiguration=InitialConfiguration,plot_func="q",N_bootstrap=10000,i1=0,i2=5,
                            FrameTension=FrameTension,Simulation=Simulation,FTMethod=FTMethod,
                            fig=fig,ax=ax,GroupBy=["EPS"])
# Out:
# ingenting
# ingenting
# ingenting

# %%
Simulation = "OnlyVectorField"
UndulationSpectrum(EPS="2",InitialConfiguration=InitialConfiguration,plot_func="I",N_bootstrap=10000,i1=0,i2=5,
                   FrameTension=FrameTension,Simulation=Simulation,FTMethod=FTMethod)

# %%
Simulation = "OnlyVectorField"
UndulationSpectrum(EPS="5",InitialConfiguration=InitialConfiguration,plot_func="I",N_bootstrap=10000,i1=0,i2=5,
                   FrameTension=FrameTension,Simulation=Simulation,FTMethod=FTMethod)

# %%
sfdsfd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 sfdsfd
#
# NameError: name 'sfdsfd' is not defined

# %%
Simulation = "VectorFieldMembrane"
EPS="10"
KPKL_list=[(0.1,0.05),(1,0.5),(10,5)]
for KPKL in KPKL_list:
# start bootstrapping
    for N_k in (3,5,8):
        values = np.genfromtxt(
            f"/lustre/astro/semygind/Analyzer/version_1/{Simulation}/EPS{EPS}/KP{KPKL[0]}KL{KPKL[1]}/StaticUndulationSpectrum/{FTMethod}{N_k}.txt",
#            /lustre/astro/semygind/Analyzer/version_1/VectorFieldMembrane/EPS10/KP0.1KL0.05/StaticUndulationSpectrum/LSFT3.txt
            skip_header=7,
            delimiter=" ",
        )
        
        mean, err = bootstrap(values,N_bootstrap)
        #r"$n \pm \sigma_n$",r"$\kappa",r"$\kappa_{\parallel}$",r"\kappa_{perpindicular}$",r"$\epsilon$",r"$\xi$",r"$N_k$"
        table_data.append([
        rf"${mean[1]:.2f} \pm {err[1]:.2f}$",
        rf"${kappa}$",
        rf"${KPKL[0]}$",
        rf"${KPKL[1]}$",
        rf"${EPS}$",
        rf"$0$",
        rf"{N_k}"
        ])

    #_ = plt.hist(bootstrap_params[:,1], bins='scott', density=True, label=rf"PDF $N_k={N_k}$")
    #mu, std = norm.fit(bootstrap_params[:,1])
    #x = np.linspace(bootstrap_params[:,1].min(), bootstrap_params[:,1].max(), 300)
    #plt.plot(x, norm.pdf(x, mean, ), color='red', label=rf"$n={mu:.2f},\ \sigma={std:.2f}$")
    #plt.vlines(mu,0,norm.pdf(mu,mu,std),color="black",label="Mean",linestyles="dashed")
    #plt.legend()
    # 4.46
    # N_k5 -> 4.46
    # N_k7 -> 4.47
    # 100k -> 
#plt.show()
